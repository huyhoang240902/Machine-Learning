# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler   #for scaling data
from sklearn.cluster import KMeans #for K-mean Cluster

# %%
data=pd.read_csv('C:/Users/Admin/Downloads/17_Dang Pham Huy Hoang_Ch3_NBC.csv')
data
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
data.isnull().sum()
# Out:
# type                     0
# fixed acidity           10
# volatile acidity         8
# citric acid              3
# residual sugar           2
# chlorides                2
# free sulfur dioxide      0
# total sulfur dioxide     0
# density                  0
# pH                       9
# sulphates                4
# alcohol                  0
# quality                  0
# dtype: int64

# %%
data.corr()
# Out:
#                       fixed acidity  volatile acidity  citric acid  \
# fixed acidity              1.000000          0.220172     0.323736
# volatile acidity           0.220172          1.000000    -0.378061
# citric acid                0.323736         -0.378061     1.000000
# residual sugar            -0.112319         -0.196702     0.142486
# chlorides                  0.298421          0.377167     0.039315
# free sulfur dioxide       -0.283317         -0.353230     0.133437
# total sulfur dioxide      -0.329747         -0.414928     0.195218
# density                    0.459204          0.271193     0.096320
# pH                        -0.251814          0.260660    -0.328689
# sulphates                  0.300380          0.225476     0.057613
# alcohol                   -0.095603         -0.038248    -0.010433
# quality                   -0.077031         -0.265953     0.085706
#
#                       residual sugar  chlorides  free sulfur dioxide  \
# ...

# %%
data['fixed acidity'].fillna(data['fixed acidity'].mean(), inplace=True)
data['volatile acidity'].fillna(data['volatile acidity'].mean(), inplace=True)
data['citric acid'].fillna(data['citric acid'].mean(), inplace=True)
data['residual sugar'].fillna(data['residual sugar'].mean(), inplace=True)
data['chlorides'].fillna(data['chlorides'].mean(), inplace=True)
data['pH'].fillna(data['pH'].mean(), inplace=True)
data['sulphates'].fillna(data['sulphates'].mean(), inplace=True)

# %%
data = data.drop(data[data.type == 'white'].index)

# %%
data['type'].unique()
# Out:
# array(['red'], dtype=object)

# %%
data.corr()
# Out:
#                       fixed acidity  volatile acidity  citric acid  \
# fixed acidity              1.000000         -0.255221     0.671140
# volatile acidity          -0.255221          1.000000    -0.552993
# citric acid                0.671140         -0.552993     1.000000
# residual sugar             0.114862          0.001948     0.143343
# chlorides                  0.093588          0.061750     0.203758
# free sulfur dioxide       -0.154137         -0.012441    -0.058749
# total sulfur dioxide      -0.113663          0.074567     0.035820
# density                    0.668060          0.023568     0.364539
# pH                        -0.681656          0.234303    -0.540134
# sulphates                  0.184852         -0.261796     0.315198
# alcohol                   -0.061605         -0.204749     0.110907
# quality                    0.123905         -0.390994     0.226967
#
#                       residual sugar  chlorides  free sulfur dioxide  \
# ...

# %%
inputs=data[['fixed acidity','volatile acidity','citric acid','sulphates','alcohol']]
target=data.quality

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(inputs,target,test_size=0.3)

# %%
from sklearn.naive_bayes import GaussianNB
model = GaussianNB()

# %%
model.fit(X_train,y_train)
# Out:
# GaussianNB()

# %%
model.score(X_test,y_test)
# Out:
# 0.8041666666666667

# %%
X_test[0:10]
# Out:
#       fixed acidity  volatile acidity  citric acid  sulphates    alcohol
# 1486            6.8             0.680         0.21       0.60  10.300000
# 1475            5.3             0.470         0.11       0.88  13.566667
# 247             8.2             0.600         0.17       0.45   9.300000
# 568             9.8             0.500         0.49       0.79  10.700000
# 997             5.6             0.660         0.00       0.63  12.800000
# 832            10.4             0.440         0.42       0.86   9.900000
# 490             9.3             0.775         0.27       0.67  10.600000
# 1455            6.5             0.900         0.00       0.63  10.900000
# 1279            9.8             0.300         0.39       0.57  11.500000
# 909             7.3             0.305         0.39       0.52  11.500000

# %%
y_test[0:10]
# Out:
# 1486    Medium
# 1475      High
# 247     Medium
# 568     Medium
# 997       High
# 832        Low
# 490     Medium
# 1455    Medium
# 1279      High
# 909     Medium
# Name: quality, dtype: object

# %%
model.predict(X_test[0:10])
# Out:
# array(['Medium', 'High', 'Medium', 'Medium', 'Medium', 'Medium', 'Medium',
#        'Medium', 'Medium', 'Medium'], dtype='<U6')
